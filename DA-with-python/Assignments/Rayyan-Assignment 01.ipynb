# %% [markdown]
# # Part -1 Python Basics (Variables)

# %% [markdown]
# 1. Print Your Name with your Father name and Date of birth using suitable escape sequence charactor

# %%
print("Name:\tMuhammad Rayyan Yaseen\nFather Name:\tYaseen afi\nD-O-B:\tDecember 13, 2006")
# Out:
# Name:	Muhammad Rayyan Yaseen
# Father Name:	Yaseen afi
# D-O-B:	December 13, 2006

# %% [markdown]
# 2. Write your small bio using variables and print it using print function

# %%
name = "Muhammad Rayyan Yaseen"
profession = "student of BSBA at SZABIST"
hobby = "love to play taken 8"

print("Hello. My name is " + name + " currently a " + profession + ", I " + hobby + ".")
# Out:
# Hello. My name is Muhammad Rayyan Yaseen currently a student of BSBA at SZABIST, I love to play taken 8.

# %% [markdown]
# 3. Write a program in which use all the operators we can use in Python

# %%
a = 10
b = 5

# Arithmetic operator
sum = a + b

# Relational operator
result = a > b

# Logical operator
check = (a > b) and (b > 0)

# Assignment operator
a += 2

print("Arithmetic:", sum)
print("Relational:", result)
print("Logical:", check)
print("Assignment:", a)
# Out:
# Hellow world

# %% [markdown]
# 4. Completes the following steps of small task:
#     - Mention Marks of English , Islamiat and Maths out of 100 in 3 different variables
#     - Mention Variable of Total Marks and assign 300 to it
#     - Calculate Percentage

# %%
english = float(input("Enter your English marks: "))
islamiat = float(input("Enter your Islamiat marks: "))
maths = float(input("Enter your Maths marks: "))

total_marks = 300
obtained_marks = english + islamiat + maths
percentage = (obtained_marks / total_marks) * 100
print(f"{percentage:.2f}%")
# Out:
# 88.00%

# %% [markdown]
# 5. Take the values of two variables `a` and `b`, then swap their values without using a third variable and print the result before and after swapping

# %% [markdown]
# 6. Take the radius of a circle from a variable and calculate its Area and Circumference (use `pi = 3.14159`)

# %%
radius = float(input("Enter the radius: "))

pi = 3.14159

area = pi * radius * radius
circumference = 2 * pi * radius

print("Area of circle:", area)
print("Circumference of circle:", circumference)
# Out:
# Area of circle: 3848.44775
# Circumference of circle: 219.91129999999998

# %% [markdown]
# 7. Take the price of an item and a discount percentage in variables, then calculate and print the discount amount and the final price after discount

# %%
price = int(input("Enter the price: "))
discount_percentage = float(input("Enter the discount percentage: "))

discount_amount = price * discount_percentage / 100
final_price = price - discount_amount

print("Discount amount:", discount_amount)
print("Final price:", final_price)
# Out:
# Discount amount: 180.0
# Final price: 1020.0
